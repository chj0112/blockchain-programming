# %% [markdown]
# # 블록체인프로그래밍 10주

# %% [markdown]
# ## StudentCrud.sol 구현

# %%
# %%writefile src/StudentCrud.sol
# //SPDX-License-Identifier: GPL-3.0-or-later
# pragma solidity ^0.8.0;
#
# contract StudentCrud {
#     struct Student {
#         uint num;
#         string name;
#         bool isEnrolled;
#     }
#     Student[] s;
#     Student temp;
#     //memory only for string type
#     //201711111,"kim",false
#     function insert(uint n, string memory sn, bool e) public {
#         temp.num = n;
#         temp.name = sn;
#         temp.isEnrolled = e;
#         s.push(temp);
#     }
#     function getFirstStudent() public view returns(uint, string memory, bool){
#         return (s[0].num, s[0].name, s[0].isEnrolled);
#     }
#     function findBy(uint8 index) view public returns(uint, string memory, bool) {
#         return (s[index].num, s[index].name, s[index].isEnrolled);
#     }
#     function remove(uint index) public {
#         require(index < s.length);
#         s[index] = s[s.length - 1];
#         s.pop();
#     }
#     function getLength() view public returns(uint) {
#         return s.length;
#     }
#     function pop() public {
#         s.pop();
#     }
# }
# Out:
# Writing src/StudentCrud.sol

# %% [markdown]
# * 삭제함수는 배열의 맨 마지막 값을 삭제하고자 하는 인덱스에 복사하고 마지막 값을 pop을 이용해 삭제하는 방식으로 구현함.

# %% [markdown]
# ## 배포
# ### 로그
# ```
# creation of StudentCrud pending...
# [vm]from: 0x5B3...eddC4to: StudentCrud.(constructor)value: 0 weidata: 0x608...70033logs: 0hash: 0xee1...2fdcd
# status	true Transaction mined and execution succeed
# transaction hash	0xee12600727d79453b183b527ad6e4c3cc8e763552754bc7ad79233aca9d2fdcd
# from	0x5B38Da6a701c568545dCfcB03FcB875f56beddC4
# to	StudentCrud.(constructor)
# gas	834018 gas
# transaction cost	725233 gas
# execution cost	725233 gas
# input	0x608...70033
# decoded input	{}
# decoded output	 -
# logs	[]
# val	0 wei
# ```
# ## (1) 아래 항목을 입력
# ```
# 201711111,"kim",false
# 201711112, "park", true
# 201711113, "lee", false
# 201711114, "lim", false
# ```
# ### 로그
# ```
# transact to StudentCrud.insert pending ...
# [vm]from: 0x5B3...eddC4to: StudentCrud.insert(uint256,string,bool) 0x358...D5eE3value: 0 weidata: 0xf07...00000logs: 0hash: 0x6ef...2010e
# status	true Transaction mined and execution succeed
# transaction hash	0x6ef7ea7968da8242b9f786c61d6bea5ba76f13a647d1031ef634bd1d1992010e
# from	0x5B38Da6a701c568545dCfcB03FcB875f56beddC4
# to	StudentCrud.insert(uint256,string,bool) 0x358AA13c52544ECCEF6B0ADD0f801012ADAD5eE3
# gas	160800 gas
# transaction cost	139826 gas
# execution cost	139826 gas
# input	0xf07...00000
# decoded input	{
# 	"uint256 n": "201711111",
# 	"string sn": "kim",
# 	"bool e": false
# }
# decoded output	{}
# logs	[]
# val	0 wei
# transact to StudentCrud.insert pending ...
# [vm]from: 0x5B3...eddC4to: StudentCrud.insert(uint256,string,bool) 0x358...D5eE3value: 0 weidata: 0xf07...00000logs: 0hash: 0x387...b5663
# status	true Transaction mined and execution succeed
# transaction hash	0x387c9e9aa410c43ed7cec611b311818d64228d430d8e50e30b3e93a57c9b5663
# from	0x5B38Da6a701c568545dCfcB03FcB875f56beddC4
# to	StudentCrud.insert(uint256,string,bool) 0x358AA13c52544ECCEF6B0ADD0f801012ADAD5eE3
# gas	150199 gas
# transaction cost	130607 gas
# execution cost	130607 gas
# input	0xf07...00000
# decoded input	{
# 	"uint256 n": "201711112",
# 	"string sn": "park",
# 	"bool e": true
# }
# decoded output	{}
# logs	[]
# val	0 wei
# transact to StudentCrud.insert pending ...
# [vm]from: 0x5B3...eddC4to: StudentCrud.insert(uint256,string,bool) 0x358...D5eE3value: 0 weidata: 0xf07...00000logs: 0hash: 0xf2e...9b503
# status	true Transaction mined and execution succeed
# transaction hash	0xf2e4c009d535c631261cde204bfffb699472372448fe321f3982c5193069b503
# from	0x5B38Da6a701c568545dCfcB03FcB875f56beddC4
# to	StudentCrud.insert(uint256,string,bool) 0x358AA13c52544ECCEF6B0ADD0f801012ADAD5eE3
# gas	107621 gas
# transaction cost	88783 gas
# execution cost	88783 gas
# input	0xf07...00000
# decoded input	{
# 	"uint256 n": "201711113",
# 	"string sn": "lee",
# 	"bool e": false
# }
# decoded output	{}
# logs	[]
# val	0 wei
# transact to StudentCrud.insert pending ...
# [vm]from: 0x5B3...eddC4to: StudentCrud.insert(uint256,string,bool) 0x358...D5eE3value: 0 weidata: 0xf07...00000logs: 0hash: 0xe42...2b6e5
# status	true Transaction mined and execution succeed
# transaction hash	0xe4253a33a20b47021a2611d4d091d8103da8496336edeca3950176cc6ee2b6e5
# from	0x5B38Da6a701c568545dCfcB03FcB875f56beddC4
# to	StudentCrud.insert(uint256,string,bool) 0x358AA13c52544ECCEF6B0ADD0f801012ADAD5eE3
# gas	104401 gas
# transaction cost	90783 gas
# execution cost	90783 gas
# input	0xf07...00000
# decoded input	{
# 	"uint256 n": "201711114",
# 	"string sn": "lim",
# 	"bool e": false
# }
# decoded output	{}
# logs	[]
# val	0 wei
# ```
# ## (2) 2번째 데이터 201711112 제거
# ### 로그
# ```
# transact to StudentCrud.remove pending ...
# [vm]from: 0x5B3...eddC4to: StudentCrud.remove(uint256) 0x358...D5eE3value: 0 weidata: 0x4cc...00001logs: 0hash: 0x7e9...e546c
# status	true Transaction mined and execution succeed
# transaction hash	0x7e994b82c4b3fa1288aa56e8096585138c4d707a9cc4f13396d3ebb21d4e546c
# from	0x5B38Da6a701c568545dCfcB03FcB875f56beddC4
# to	StudentCrud.remove(uint256) 0x358AA13c52544ECCEF6B0ADD0f801012ADAD5eE3
# gas	70130 gas
# transaction cost	46582 gas
# execution cost	46582 gas
# input	0x4cc...00001
# decoded input	{
# 	"uint256 index": "1"
# }
# decoded output	{}
# logs	[]
# val	0 wei
# ```
# ## (3) 배열크기 조회 (4개 항목에서 1개가 제거되었으니 3이 출력)
# ### 로그
# ```
# call to StudentCrud.getLength
# CALL
# [call]from: 0x5B38Da6a701c568545dCfcB03FcB875f56beddC4to: StudentCrud.getLength()data: 0xbe1...c766b
# from	0x5B38Da6a701c568545dCfcB03FcB875f56beddC4
# to	StudentCrud.getLength() 0x358AA13c52544ECCEF6B0ADD0f801012ADAD5eE3
# execution cost	23553 gas (Cost only applies when called by a contract)
# input	0xbe1...c766b
# decoded input	{}
# decoded output	{
# 	"0": "uint256: 3"
# }
# logs	[]
# ```
# ## (4) 2 번째 데이터조회를 조회한다. 20171112는 삭제되어서 출력할 수 없고, 다른 데이터 항목이 출력.
# ### 로그
# ```
# call to StudentCrud.findBy
# CALL
# [call]from: 0x5B38Da6a701c568545dCfcB03FcB875f56beddC4to: StudentCrud.findBy(uint8)data: 0xedf...00001
# from	0x5B38Da6a701c568545dCfcB03FcB875f56beddC4
# to	StudentCrud.findBy(uint8) 0x358AA13c52544ECCEF6B0ADD0f801012ADAD5eE3
# execution cost	32091 gas (Cost only applies when called by a contract)
# input	0xedf...00001
# decoded input	{
# 	"uint8 index": 1
# }
# decoded output	{
# 	"0": "uint256: 201711114",
# 	"1": "string: lim",
# 	"2": "bool: false"
# }
# logs	[]
# ```
# ## (5) 첫 데이터 조회
# ### 로그
# ```
# call to StudentCrud.getFirstStudent
# CALL
# [call]from: 0x5B38Da6a701c568545dCfcB03FcB875f56beddC4to: StudentCrud.getFirstStudent()data: 0xacb...e8cee
# from	0x5B38Da6a701c568545dCfcB03FcB875f56beddC4
# to	StudentCrud.getFirstStudent() 0x358AA13c52544ECCEF6B0ADD0f801012ADAD5eE3
# execution cost	31618 gas (Cost only applies when called by a contract)
# input	0xacb...e8cee
# decoded input	{}
# decoded output	{
# 	"0": "uint256: 201711111",
# 	"1": "string: kim",
# 	"2": "bool: false"
# }
# logs	[]
# ```
